# %% [markdown]
# <a href="https://colab.research.google.com/github/shandiyashreepb24mss061-cell/DSL-KDD-DATASET-SET-INTRSION-DETECTION-AND-NETWORK-ATTACK-RECORD/blob/main/Copy_of_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files

# %%
dp=files.upload()
# Out:
#      <input type="file" id="files-747c0141-14fa-4d94-8a5c-2d9590f301db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-747c0141-14fa-4d94-8a5c-2d9590f301db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('kdd_test.csv.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

data = pd.read_csv('kdd_test.csv')

# %%
df=pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22544 entries, 0 to 22543
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     22544 non-null  int64
#  1   protocol_type                22544 non-null  object
#  2   service                      22544 non-null  object
#  3   flag                         22544 non-null  object
#  4   src_bytes                    22544 non-null  int64
#  5   dst_bytes                    22544 non-null  int64
#  6   land                         22544 non-null  int64
#  7   wrong_fragment               22544 non-null  int64
#  8   urgent                       22544 non-null  int64
#  9   hot                          22544 non-null  int64
#  10  num_failed_logins            22544 non-null  int64
#  11  logged_in                    22544 non-null  int64
#  12  num_compromised              22544 non-null  int64
# ...

# %%
df.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  22544.000000  2.254400e+04  2.254400e+04  22544.000000    22544.000000
# mean     258.858499  1.226873e+04  2.966787e+03      0.000089        0.016989
# std     2184.355090  4.665783e+05  6.293205e+04      0.009419        0.217507
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  4.500000e+01  0.000000e+00      0.000000        0.000000
# 75%        0.000000  2.750000e+02  5.950000e+02      0.000000        0.000000
# max    54451.000000  6.282565e+07  5.153771e+06      1.000000        3.000000
#
#              urgent           hot  num_failed_logins     logged_in  \
# count  22544.000000  22544.000000       22544.000000  22544.000000
# mean       0.000177      0.155562           0.008783      0.406095
# ...

# %%
df.isnull()
# Out:
#        duration  protocol_type  service   flag  src_bytes  dst_bytes   land  \
# 0         False          False    False  False      False      False  False
# 1         False          False    False  False      False      False  False
# 2         False          False    False  False      False      False  False
# 3         False          False    False  False      False      False  False
# 4         False          False    False  False      False      False  False
# ...         ...            ...      ...    ...        ...        ...    ...
# 22539     False          False    False  False      False      False  False
# 22540     False          False    False  False      False      False  False
# 22541     False          False    False  False      False      False  False
# 22542     False          False    False  False      False      False  False
# 22543     False          False    False  False      False      False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22539    False
# 22540    False
# 22541    False
# 22542    False
# 22543    False
# Length: 22544, dtype: bool

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['duration'],color="red",bins=4)
# Out:
# (array([2.243e+04, 7.100e+01, 3.600e+01, 7.000e+00]),
#  array([    0.  , 13612.75, 27225.5 , 40838.25, 54451.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.scatter(df['protocol_type'],df['service'],color="blue")

# %%
plt.show()

# %%
plt.title("duration vs service")
plt.xlabel("duration")
plt.ylabel("service")
# Out:
# Text(0, 0.5, 'service')

# %%
plt.xlabel("duration")
# Out:
# Text(0.5, 0, 'duration')

# %%
plt.ylabel("protocal")
# Out:
# Text(0, 0.5, 'protocal')

# %%
plt.show()

# %%
plt.pie(df['duration'],labels=df['service'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7c2d18ea94f0>,
# ...
# ...
#   Text(1.0799589721818197, 0.20901822505223755, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'domain_u'),
#   Text(1.0798709978925871, 0.20947226047968365, 'netbios_ssn'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'ftp'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'private'),
#   Text(1.0798709978925871, 0.20947226047968365, 'other'),
#   Text(1.0798709978925871, 0.20947226047968365, 'ftp_data'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'private'),
#   Text(1.0798709978925871, 0.20947226047968365, 'uucp_path'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'private'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
# ...

# %%
plt.show()

# %%
plt.plot(df['service'],df['duration'],color="blue")

# %%
plt.title("duration vs service")
plt.xlabel("duration")
plt.ylabel("service")
# Out:
# Text(0, 0.5, 'service')

# %%
plt.xlabel("duration")
# Out:
# Text(0.5, 0, 'duration')

# %%
plt.ylabel("service")
# Out:
# Text(0, 0.5, 'service')

# %%
plt.show()

# %%
plt.subplot(1,1,1)
# Out:
# <Axes: >

# %%
plt.plot(df['duration'],df['service'],color="red")

# %%
plt.hist(df['duration'], bins=50, color='skyblue', edgecolor='red')
plt.xlabel("duration")
plt.ylabel('Frequency')
plt.title('Distribution of Duration')
plt.show()

# %%
plt.xlabel("duration")
# Out:
# Text(0.5, 0, 'duration')

# %%
plt.ylabel('service')
# Out:
# Text(0, 0.5, 'service')

# %%
unique_protocols = df['protocol_type'].unique()
print(unique_protocols)
# Out:
# ['tcp' 'udp' 'icmp']

# %%
plt.subplot(1,1,1)
# Out:
# <Axes: >

# %%
plt.pie(df['duration'],labels=df['service'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7c2d004721e0>,
# ...
# ...
#   Text(1.0799589721818197, 0.20901822505223755, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'domain_u'),
#   Text(1.0798709978925871, 0.20947226047968365, 'netbios_ssn'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'ftp'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'private'),
#   Text(1.0798709978925871, 0.20947226047968365, 'other'),
#   Text(1.0798709978925871, 0.20947226047968365, 'ftp_data'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'private'),
#   Text(1.0798709978925871, 0.20947226047968365, 'uucp_path'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
#   Text(1.0798709978925871, 0.20947226047968365, 'private'),
#   Text(1.0798709978925871, 0.20947226047968365, 'http'),
# ...

# %%
plt.subplot(1,1,1)
# Out:
# <Axes: >

# %%
plt.xlabel("duration")
# Out:
# Text(0.5, 0, 'duration')

# %%
plt.ylabel("service")
# Out:
# Text(0, 0.5, 'service')

# %%
plt.subplot(1, 1, 1)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
df['service'].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Distribution of Service Types')
plt.xlabel('Service Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.show()

# %%
df
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             5           tcp      smtp    SF       2429        475     0
# 1             0           udp  domain_u    SF         45        134     0
# 2             0           udp  domain_u    SF         45         80     0
# 3          1979           udp     other    SF        145        105     0
# 4         14462           tcp     other  RSTR          1          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp   private   REJ          0          0     0
# 22540         0           tcp      http    SF        254       2277     0
# 22541         0           tcp   private    S0          0          0     0
# 22542         0           tcp   private  RSTR          0          0     0
# 22543         0           udp  domain_u    SF         44        129     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...
